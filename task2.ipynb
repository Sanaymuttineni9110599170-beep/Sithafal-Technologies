# %%
pip install requests beautifulsoup4 openai faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: requests in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (4.12.3)
# Requirement already satisfied: openai in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (1.57.4)
# Requirement already satisfied: faiss-cpu in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (1.9.0.post1)
# Requirement already satisfied: sentence-transformers in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (3.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from faiss-cpu) (2.2.0)
# Requirement already satisfied: packaging in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sentence-transformers) (4.47.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sentence-transformers) (0.26.5)
# Requirement already satisfied: Pillow in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: networkx in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanay\desktop\sithaphal\myenv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import faiss  # Make sure you import FAISS
from sentence_transformers import SentenceTransformer

# Step 1: Scrape Website Content (using the UND URL)
def scrape_website(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract paragraphs and other relevant sections (we're still scraping all 'p' tags here)
    paragraphs = soup.find_all('p')
    content = " ".join([para.get_text() for para in paragraphs])

    return content

# Step 2: Chunk the Content (break into smaller pieces)
def chunk_content(content, chunk_size=1000):
    # Chunk the content into smaller sections
    chunks = [content[i:i+chunk_size] for i in range(0, len(content), chunk_size)]
    return chunks

# Step 3: Embed the Chunks using Sentence Transformer
def embed_chunks(chunks, model):
    embeddings = model.encode(chunks)
    return embeddings

# Step 4: Initialize FAISS Index
def create_faiss_index(embeddings):
    dimension = embeddings.shape[1]  # Should match the embedding dimension (e.g., 384 for all-MiniLM-L6-v2)
    faiss_index = faiss.IndexFlatL2(dimension)  # FAISS index for cosine similarity search
    faiss_index.add(embeddings)
    return faiss_index

# Step 5: Query Index Function (to search for relevant chunks)
def query_index(query, faiss_index, model, metadata, top_k=5):
    # Embed the query
    query_embedding = model.encode([query])
    query_embedding = np.array(query_embedding, dtype=np.float32)

    # Perform similarity search using FAISS
    distances, indices = faiss_index.search(query_embedding, top_k)

    # Retrieve the top-k results based on indices
    results = [metadata[idx] for idx in indices[0]]
    return results

# Example usage:

# Step 6: Scrape, chunk, embed, and create FAISS index
url = "https://und.edu/"  # University of North Dakota URL
scraped_content = scrape_website(url)

# Chunk the scraped content
chunks = chunk_content(scraped_content)

# Load pre-trained SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Embed the chunks
chunk_embeddings = embed_chunks(chunks, model)

# Create FAISS index from the embeddings
faiss_index = create_faiss_index(chunk_embeddings)

# Step 7: Save metadata (for referencing the chunks)
metadata = [{"text": chunk, "source": url} for chunk in chunks]

# Step 8: Query example: "What programs are offered at the University of North Dakota?"
query = "What programs are offered at the University of North Dakota?"
retrieved_results = query_index(query, faiss_index, model, metadata)

# Print the top-k results
for result in retrieved_results:
    print(f"Source: {result['source']}\nText: {result['text']}\n")
# Out:
# Source: https://und.edu/
# Text: The University of North Dakota is the state's oldest and largest university. We offer
#                            225+ highly accredited on-campus and online degrees. Explore the causes and impact of criminal behavior and prepare to play a key role
#                                     in criminal justice. Immerse yourself in teaching and prepare for a rewarding career educating grades 1-8. Join a UAS ecosystem that puts you on the cutting edge of what’s next in the industry.																																																																																																																																																																																																						 A high-demand field, you'll drive positive business decisions with meaningful data.																																																																																																								 Our students embark on a journey to become leaders. Not just in what they say, but
#                            what they do. Through hard
#
# Source: https://und.edu/
# Text:  work and determination, we believe in work worth doing. Student has dream of being like the music teachers that inspired her. Online learning option is perfect for student living in western North Dakota. After facing personal challenges, a student returns to school to help others heal
#                                     and thrive.
#                            We value diverse peoples, perspectives and ideas. We take active steps to ensure a
#                            sense of belonging and equity for all.
#
#                                     The University of North Dakota values, honors, and supports all members of our campus
#                                     community.
#
#                                     1 in 7 UND students are veterans, active duty, spouses, or military dependents.
#
#                                     The Clothesline Project and Take Back the Night Rally educate
#
# Source: https://und.edu/
# Text: and bring awareness
#                                     to interpersonal violence.
#
#                                     We provide qualified students with disabilities an equal opportunity to participate
#                                     in all UND activities.
#                                      Proud to be a Fighting Hawk? Use #UNDproud to be featured. Content is moderated. UND consistently ranks among the best for educational quality, affordability and career
#                         outcomes
#         By clicking any link on this page you are giving your consent for us
#         to set cookies, Privacy Information.
#        © 2024 University of North Dakota - Grand Forks, ND - Member of ND University System
#
# Source: https://und.edu/
# Text: and bring awareness
#                                     to interpersonal violence.
#
#                                     We provide qualified students with disabilities an equal opportunity to participate
#                                     in all UND activities.
#                                      Proud to be a Fighting Hawk? Use #UNDproud to be featured. Content is moderated. UND consistently ranks among the best for educational quality, affordability and career
#                         outcomes
#         By clicking any link on this page you are giving your consent for us
#         to set cookies, Privacy Information.
#        © 2024 University of North Dakota - Grand Forks, ND - Member of ND University System
#
# Source: https://und.edu/
# Text: and bring awareness
#                                     to interpersonal violence.
#
#                                     We provide qualified students with disabilities an equal opportunity to participate
#                                     in all UND activities.
#                                      Proud to be a Fighting Hawk? Use #UNDproud to be featured. Content is moderated. UND consistently ranks among the best for educational quality, affordability and career
#                         outcomes
#         By clicking any link on this page you are giving your consent for us
#         to set cookies, Privacy Information.
#        © 2024 University of North Dakota - Grand Forks, ND - Member of ND University System

# %%
# Scrape the website content
from bs4 import BeautifulSoup
import requests

def scrape_website(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract paragraphs or other relevant tags
    paragraphs = soup.find_all('p')
    content = " ".join([para.get_text() for para in paragraphs])
    return content

# Example:
url = "https://und.edu/"
scraped_content = scrape_website(url)
print(scraped_content[:500])  # View first 500 characters of the content
# Out:
# The University of North Dakota is the state's oldest and largest university. We offer
#                            225+ highly accredited on-campus and online degrees. Explore the causes and impact of criminal behavior and prepare to play a key role
#                                     in criminal justice. Immerse yourself in teaching and prepare for a rewarding career educating grades 1-8. Join a UAS ecosystem that puts you on the cutting edge of what’s next in the industry.

# %%
# Chunk the content
def chunk_content(content, chunk_size=500):
    # Break the content into chunks of specified size
    chunks = [content[i:i+chunk_size] for i in range(0, len(content), chunk_size)]
    return chunks

# Example:
chunks = chunk_content(scraped_content)
print(chunks[:3])  # View the first three chunks
# Out:
# ["The University of North Dakota is the state's oldest and largest university. We offer\n                           225+ highly accredited on-campus and online degrees. Explore the causes and impact of criminal behavior and prepare to play a key role\n                                    in criminal justice. Immerse yourself in teaching and prepare for a rewarding career educating grades 1-8. Join a UAS ecosystem that puts you on the cutting edge of what’s next in the industry.\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t", "\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t A high-demand field, you'll drive positive business decisions with meaningful data.\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t Our students embark on a journey to become leaders. Not just in what they say, but\n                           what they do. Through hard", ' work and determination, we believe in work worth doing. Student has dream of being like the music teachers that inspired her. Online learning option is perfect for student living in western North Dakota. After facing personal challenges, a student returns to school to help others heal\n                                    and thrive. \n                           We value diverse peoples, perspectives and ideas. We take active steps to ensure a\n                           sense of belonging and equi']

# %%
# Convert the chunks into Embeddings 
from sentence_transformers import SentenceTransformer

# Load pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')

def embed_chunks(chunks, model):
    embeddings = model.encode(chunks)
    return embeddings

chunk_embeddings = embed_chunks(chunks, model)
print(chunk_embeddings.shape)  # View the shape of the embeddings
# Out:
# (6, 384)

# %%
# Build a FAISS index
import faiss
import numpy as np

def create_faiss_index(embeddings):
    dimension = embeddings.shape[1]  # Embedding dimension (e.g., 384)
    faiss_index = faiss.IndexFlatL2(dimension)  # L2 similarity index
    faiss_index.add(embeddings)
    return faiss_index

faiss_index = create_faiss_index(np.array(chunk_embeddings, dtype=np.float32))
metadata = [{"text": chunk, "source": url} for chunk in chunks]

# %%
# Query the Index
def query_index(query, faiss_index, model, metadata, top_k=5):
    # Embed the query
    query_embedding = model.encode([query])
    query_embedding = np.array(query_embedding, dtype=np.float32)

    # Perform similarity search
    distances, indices = faiss_index.search(query_embedding, top_k)

    # Retrieve the top-k results
    results = [metadata[idx] for idx in indices[0]]
    return results

# Example Query
query = "What programs are offered at the University of North Dakota?"
retrieved_results = query_index(query, faiss_index, model, metadata)

# Display results
for result in retrieved_results:
    print(f"Source: {result['source']}\nText: {result['text']}\n")
# Out:
# Source: https://und.edu/
# Text: The University of North Dakota is the state's oldest and largest university. We offer
#                            225+ highly accredited on-campus and online degrees. Explore the causes and impact of criminal behavior and prepare to play a key role
#                                     in criminal justice. Immerse yourself in teaching and prepare for a rewarding career educating grades 1-8. Join a UAS ecosystem that puts you on the cutting edge of what’s next in the industry.
#
# Source: https://und.edu/
# Text: ty for all.
#
#                                     The University of North Dakota values, honors, and supports all members of our campus
#                                     community.
#
#                                     1 in 7 UND students are veterans, active duty, spouses, or military dependents.
#
#                                     The Clothesline Project and Take Back the Night Rally educate
#
# Source: https://und.edu/
# Text:  work and determination, we believe in work worth doing. Student has dream of being like the music teachers that inspired her. Online learning option is perfect for student living in western North Dakota. After facing personal challenges, a student returns to school to help others heal
#                                     and thrive.
#                            We value diverse peoples, perspectives and ideas. We take active steps to ensure a
#                            sense of belonging and equi
#
# Source: https://und.edu/
# Text: areer
#                         outcomes
#         By clicking any link on this page you are giving your consent for us
#         to set cookies, Privacy Information.
#        © 2024 University of North Dakota - Grand Forks, ND - Member of ND University System
#
# Source: https://und.edu/
# Text: and bring awareness
#                                     to interpersonal violence.
#
#                                     We provide qualified students with disabilities an equal opportunity to participate
#                                     in all UND activities.
#                                      Proud to be a Fighting Hawk? Use #UNDproud to be featured. Content is moderated. UND consistently ranks among the best for educational quality, affordability and c
